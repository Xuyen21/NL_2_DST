# %%
import erdantic as erd
from text_to_json.schema_design import DomainStory

diagram = erd.create(DomainStory)
diagram
# Out:
# EntityRelationshipDiagram(
#     models={
#         'text_to_json.schema_design.Activity': ModelInfo(...),
#         'text_to_json.schema_design.Actor': ModelInfo(...),
#         'text_to_json.schema_design.DomainStory': ModelInfo(...),
#         'text_to_json.schema_design.Icon': ModelInfo(...),
#         'text_to_json.schema_design.MainActivity': ModelInfo(...),
#         'text_to_json.schema_design.SubActivity': ModelInfo(...),
#         'text_to_json.schema_design.WorkObject': ModelInfo(...),
#         'text_to_json.schema_design.WorkObjectInstance': ModelInfo(...)
#     },
#     edges={
#         'text_to_json.schema_design.Activity-main_activity-text_to_json.schema_design.MainActivity': Edge(...),
#         'text_to_json.schema_design.Activity-sub_activities-text_to_json.schema_design.SubActivity': Edge(...),
#         'text_to_json.schema_design.DomainStory-activities-text_to_json.schema_design.Activity': Edge(...),
# ...
